# %%
from pypath import api

# %% [markdown]
# # Methods -
# 1. getAllRoutes
# 2. getAllStoppages
# 3. getVehicleListByRecBoundary
# 4. getVehicleListByCirBoundary
# 5. getVehicleETA
# 6. getVehicleByRoute
# 7. getPointByRoute
# 8. getTripPlans
# 9. findNearestStop
# 10. getStoppagesInBoundary
# 11. getVehiclePosition
# 12. getRoutePathBetween2Stops
# 13. getTokenForRideShare
# 14. getApproachingVehicles
# 15. getLastRoueUpdateTime
# 16. getKolkataTrafficUpdate

# %%
a=api()
a.get_all_stoppages()
# Out:
# {'requestId': '5040c1e0-93e3-4e51-a34b-e79c838dd052',
#  'duration': 1,
#  'status': 'SUCCESS',
#  'message': '',
#  'count': 1682,
#  'data': [{'stopId': 1,
#    'stopName': 'AIRPORT (GATE NO.1)',
#    'stopLat': 22.642036,
#    'stopLon': 88.431122,
#    'locationType': 'TERMINAL',
#    'isJunction': 'Y',
#    'isValid': 'Y'},
#   {'stopId': 2,
#    'stopName': 'AIRPORT (GATE NO.3)',
#    'stopLat': 22.652987,
#    'stopLon': 88.438289,
#    'locationType': 'TERMINAL',
#    'isJunction': 'Y',
#    'isValid': 'Y'},
#   {'stopId': 3,
#    'stopName': 'AJOY NAGAR',
#    'stopLat': 22.4897,
#    'stopLon': 88.395331,
#    'locationType': 'JUNCTION',
#    'isJunction': 'Y',
#    'isValid': 'Y'},
#   {'stopId': 5,
#    'stopName': 'ALAMPUR',
#    'stopLat': 22.584474,
#    'stopLon': 88.214893,
#    'locationType': 'STOP',
#    'isJunction': 'N',
#    'isValid': 'Y'},
#   {'stopId': 6,
#    'stopName': 'ALIPORE (LALBATI)',
#    'stopLat': 22.525084,
#    'stopLon': 88.330894,
# ...

# %%
a.get_all_routes()
# Out:
# {'requestId': '9d02de27-5ec7-45ab-b097-f715a9a1dba0',
#  'duration': 0,
#  'status': 'SUCCESS',
#  'message': '',
#  'count': 1190,
#  'data': [{'routeId': 6155,
#    'agency': {'agencyId': 8,
#     'agencyName': 'CTC',
#     'agencyType': 'PASSENGER_TRANSPORT',
#     'agencyTimezone': 'Asia/Kolkata'},
#    'routeShortName': 'C49:UP',
#    'routeLongName': 'BARUIPUR - NABANNA',
#    'routeType': 3,
#    'isValid': 'Y',
#    'startStop': 'BARUIPUR',
#    'endStop': 'NABANNA',
#    'skipCount': 0,
#    'hasPaths': True,
#    'routeDepotList': ['OTHER']},
#   {'routeId': 61,
#    'agency': {'agencyId': 1,
#     'agencyName': 'CSTC',
#     'agencyType': 'PASSENGER_TRANSPORT',
#     'agencyUrl': 'http://cstc.org',
#     'agencyTimezone': 'Asia/Kolkata',
#     'agencyPhone': '8798089899',
#     'agencyEmail': 'cstc@email.com'},
#    'routeShortName': 'AC4A:UP',
#    'routeLongName': 'PARNASREE - SHAPOORJI',
#    'routeType': 3,
#    'routeDepot': 'TARATALA',
#    'isValid': 'Y',
# ...

# %%
stops = a.get_all_stoppages()
routes = a.get_all_routes()
print(type(stops))
print(type(routes))
# Out:
# <class 'dict'>
# <class 'dict'>

# %%
import pandas as pd
from pandas.io.json import json_normalize
